# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Data Preprocessing
#
# Missing values were identified for all variables except for Country, Year, and GDP per Capita. Different imputation methods were used for each null values depending on the circumstances of each variable. To summarize, here are the steps done for all of the missing values:
#
# **Missing Values in 2020 for the variables: 'overallreadiness',' socialreadiness', 'economicreadiness', 'governmentreadiness', 'ecosystemvulnerability', 'exposure', 'foodvulnerability', 'habitatvulnerability', 'healthvulnerability', 'watervulnerability', 'overallvulnerability'**
# - There is no data available for all countries in the year 2020 because the source, University of. Notre Dame, has not updated it yet for the respective year.
# - To deal with the null values, we set the 2020 value of each variable to the mean value of each country for the last three years.
#
# **Missing values in 1995, 1997, 1999, and 2001 for 'publicvoiceandgovaccountabilityindex' for all. countries**
# - Since 1995 is the oldest year in the dataset, the 1996 value will be assigned to the 1995 value for each country.
# - 1997 value will be the mean of 1996 and 1998
# - 1999 value will be the mean of 1998 and 2000
# - 2001 value will be the mean of 2000 and 2002
#
# **Missing values in for 'PercGDPContributionOfAgriForestFish' for Myanmar, USA, and Canada**
# - The years of the missing values for 'PercGDPContributionOfAgriForestFish' vary per country therefore a different method was used for each.
# - **For Myanmar**
#     -  The 2001  value of the variable for Myanmar will be assigned to the missing values from 1995 to 2000.
# - **For Canada**
#     - The 1997 value of the variable for Canada will be assigned to the missing values from 1995 to 1996.
#     - There is also a missing value from 2019. The average of 2018 and 2020 values for the variable for Canada will be assigned to the missing value.
# - **For USA**
#     - The 1997 value of the variable for USA will be assigned to the missing values from 1995 to 1996.

# %%
url = 'https://raw.githubusercontent.com/idc0097/data103-project/main/data/climatedata.csv'
df = pd.read_csv(url, index_col=0)
df = df.reset_index(level=0)

# %%
#there is a total of 442 entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               442 non-null    object
#  1   Year                                  442 non-null    int64
#  2   overallreadiness                      425 non-null    float64
#  3   socialreadiness                       425 non-null    float64
#  4   economicreadiness                     425 non-null    float64
#  5   governmentreadiness                   425 non-null    float64
#  6   ecosystemvulnerability                425 non-null    float64
#  7   exposure                              425 non-null    float64
#  8   foodvulnerability                     425 non-null    float64
#  9   habitatvulnerability                  425 non-null    float64
#  10  healthvulnerability                   425 non-null    float64
#  11  watervulnerability                    425 non-null    float64
#  12  overallvulnerability                  425 non-null    float64
#  13  GDPPerCapita                          442 non-null    float64
#  14  PercGDPContributionOfAgriForestFish   428 non-null    float64
#  15  publicvoiceandgovaccountabilityindex  374 non-null    float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 55.4+ KB

# %%
df.isnull().sum()
# Out:
# Country                                  0
# Year                                     0
# overallreadiness                        17
# socialreadiness                         17
# economicreadiness                       17
# governmentreadiness                     17
# ecosystemvulnerability                  17
# exposure                                17
# foodvulnerability                       17
# habitatvulnerability                    17
# healthvulnerability                     17
# watervulnerability                      17
# overallvulnerability                    17
# GDPPerCapita                             0
# PercGDPContributionOfAgriForestFish     14
# publicvoiceandgovaccountabilityindex    68
# dtype: int64

# %%
df
# Out:
#                Country  Year  overallreadiness  socialreadiness  \
# 0    Brunei Darussalam  1995         -0.178337         0.174853
# 1             Cambodia  1995         -0.059828         0.196209
# 2            Indonesia  1995          0.015053         0.233235
# 3              Lao PDR  1995         -0.040706         0.197401
# 4              Myanmar  1995         -0.069966         0.107750
# ..                 ...   ...               ...              ...
# 437            Germany  2020               NaN              NaN
# 438              Japan  2020               NaN              NaN
# 439              Italy  2020               NaN              NaN
# 440     United Kingdom  2020               NaN              NaN
# 441      United States  2020               NaN              NaN
#
#      economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 0             0.522559             0.691582                0.399451  0.404785
# 1             0.313859             0.330263                0.463645  0.393905
# 2             0.503790             0.381178                0.475409  0.517932
# 3             0.330295             0.378320                0.557446  0.393777
# 4             0.492703             0.206757                0.559146  0.565127
# ..                 ...                  ...                     ...       ...
# 437                NaN                  NaN                     NaN       NaN
# 438                NaN                  NaN                     NaN       NaN
# 439                NaN                  NaN                     NaN       NaN
# 440                NaN                  NaN                     NaN       NaN
# 441                NaN                  NaN                     NaN       NaN
#
#      foodvulnerability  habitatvulnerability  healthvulnerability  \
# 0             0.434201              0.625081             0.396556
# 1             0.637270              0.571884             0.507440
# 2             0.602365              0.532567             0.482700
# 3             0.646768              0.551481             0.615999
# 4             0.567118              0.598676             0.675996
# ..                 ...                   ...                  ...
# 437                NaN                   NaN                  NaN
# 438                NaN                   NaN                  NaN
# 439                NaN                   NaN                  NaN
# 440                NaN                   NaN                  NaN
# 441                NaN                   NaN                  NaN
#
#      watervulnerability  overallvulnerability  GDPPerCapita  \
# 0              0.285724              0.108407  15933.452830
# 1              0.566929              0.065538    322.931575
# 2              0.418619              0.010084   1026.393436
# 3              0.461857              0.083271    363.880052
# 4              0.402766              0.075015    111.140814
# ..                  ...                   ...           ...
# 437                 NaN                   NaN  46252.689300
# 438                 NaN                   NaN  40193.252440
# 439                 NaN                   NaN  31769.965870
# 440                 NaN                   NaN  41059.168810
# 441                 NaN                   NaN  63206.521080
#
#      PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 0                               1.161528                                   NaN
# 1                              47.724560                                   NaN
# 2                              17.138346                                   NaN
# 3                              42.226236                                   NaN
# 4                                    NaN                                   NaN
# ..                                   ...                                   ...
# 437                             0.735310                              1.377576
# 438                                  NaN                              0.987699
# 439                             1.987092                              1.057024
# 440                             0.581796                              1.246781
# 441                                  NaN                              0.868937
#
# [442 rows x 16 columns]

# %%
df.Country.unique()
# Out:
# array(['Brunei Darussalam', 'Cambodia', 'Indonesia', 'Lao PDR', 'Myanmar',
#        'Malaysia', 'Philippines', 'Singapore', 'Thailand', 'Viet Nam',
#        'Canada', 'France', 'Germany', 'Japan', 'Italy', 'United Kingdom',
#        'United States'], dtype=object)

# %% [markdown]
# # Missing Values for 2020
# - The variables 'overallreadiness',' socialreadiness', 'economicreadiness', 'governmentreadiness', 'ecosystemvulnerability', 'exposure', 'foodvulnerability', 'habitatvulnerability', 'healthvulnerability', 'watervulnerability', 'overallvulnerability' have null values for 2020
# - Let us set the 2020 value of each variable to the mean value of each country for the last three years (2017 to 2019)

# %%
#store years needed in a list
col = [2020, 2019, 2018, 2017]

#create a dataframe per country that filters it out on the years that we need
df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
df_france = df[df.Country == 'France'][df['Year'].isin(col)]
df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_france = df[df.Country == 'France'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4204355935.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]

# %%
#store variables with null values in a list
col = ['overallreadiness', 'socialreadiness', 'economicreadiness', 'governmentreadiness', 'ecosystemvulnerability', 'exposure', 'foodvulnerability', 'habitatvulnerability', 'healthvulnerability', 'watervulnerability', 'overallvulnerability', 'GDPPerCapita', 'PercGDPContributionOfAgriForestFish', 'publicvoiceandgovaccountabilityindex']

#fill null values with the mean per column in col for each filtered country dataframe
df_brunei[col] = df_brunei[col].fillna(df_brunei[col].mean())
df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_france[col] = df_france[col].fillna(df_france[col].mean())
df_germany[col] = df_germany[col].fillna(df_germany[col].mean())
df_indonesia[col] = df_indonesia[col].fillna(df_indonesia[col].mean())
df_italy[col] = df_italy[col].fillna(df_italy[col].mean())
df_japan[col] = df_japan[col].fillna(df_japan[col].mean())
df_lao[col] = df_lao[col].fillna(df_lao[col].mean())
df_malaysia[col] = df_malaysia[col].fillna(df_malaysia[col].mean())
df_myanmar[col] = df_myanmar[col].fillna(df_myanmar[col].mean())
df_philippines[col] = df_philippines[col].fillna(df_philippines[col].mean())
df_singapore[col] = df_singapore[col].fillna(df_singapore[col].mean())
df_thailand[col] = df_thailand[col].fillna(df_thailand[col].mean())
df_uk[col] = df_uk[col].fillna(df_uk[col].mean())
df_usa[col] = df_usa[col].fillna(df_usa[col].mean())
df_vietnam[col] = df_vietnam[col].fillna(df_vietnam[col].mean())

#drop the last three years (2017 to 2019) since we only need the imputed rows for 2020
df_brunei.drop(df_brunei[df_brunei.Year < 2020].index, inplace=True)
df_cambodia.drop(df_cambodia[df_cambodia.Year < 2020].index, inplace=True)
df_canada.drop(df_canada[df_canada.Year < 2020].index, inplace=True)
df_france.drop(df_france[df_france.Year < 2020].index, inplace=True)
df_germany.drop(df_germany[df_germany.Year < 2020].index, inplace=True)
df_indonesia.drop(df_indonesia[df_indonesia.Year < 2020].index, inplace=True)
df_italy.drop(df_italy[df_italy.Year < 2020].index, inplace=True)
df_japan.drop(df_japan[df_japan.Year < 2020].index, inplace=True)
df_lao.drop(df_lao[df_lao.Year < 2020].index, inplace=True)
df_malaysia.drop(df_malaysia[df_malaysia.Year < 2020].index, inplace=True)
df_myanmar.drop(df_myanmar[df_myanmar.Year < 2020].index, inplace=True)
df_philippines.drop(df_philippines[df_philippines.Year < 2020].index, inplace=True)
df_singapore.drop(df_singapore[df_singapore.Year < 2020].index, inplace=True)
df_thailand.drop(df_thailand[df_thailand.Year < 2020].index, inplace=True)
df_uk.drop(df_uk[df_uk.Year < 2020].index, inplace=True)
df_usa.drop(df_usa[df_usa.Year < 2020].index, inplace=True)
df_vietnam.drop(df_vietnam[df_vietnam.Year < 2020].index, inplace=True)
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3914287117.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())

# %%
#result for Thailand
#we can see that values are no longer null and have been replaced with the mean
df_thailand
# Out:
#       Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 433  Thailand  2020          0.041921         0.344139           0.591123
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 433             0.461587                0.479188   0.45757            0.43739
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 433              0.378567             0.383287            0.442124
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 433             -0.010085   7186.874092                              8.63114
#
#      publicvoiceandgovaccountabilityindex
# 433                             -0.809891

# %%
#create copy of original and untouched dataframe
copy = df.copy()
#drop values that contain the year 2020 since we will be replacing it with the imputed 2020 values
copy = copy[~copy['Year'].isin([2020])]

# %%
#store all country dataframes with imputed values in a list
frames = [df_brunei, df_cambodia, df_canada, df_france, df_germany, df_indonesia, df_italy, 
            df_japan, df_lao, df_malaysia, df_myanmar, df_philippines, 
            df_singapore, df_thailand, df_uk, df_usa, df_vietnam, copy]

#concatenate the list with the original dataframe
#we now have a main dataframe named df_2020
df_2020 = pd.concat(frames)

# %%
#no more null values for 2020
df_2020[df_2020.Year==2020]
# Out:
#                Country  Year  overallreadiness  socialreadiness  \
# 425  Brunei Darussalam  2020         -0.120195         0.307479
# 426           Cambodia  2020         -0.066863         0.279520
# 435             Canada  2020          0.084630         0.558068
# 436             France  2020          0.095216         0.686463
# 437            Germany  2020          0.097123         0.703921
# 427          Indonesia  2020         -0.012743         0.306754
# 439              Italy  2020         -0.028500         0.540917
# 438              Japan  2020          0.182350         0.744125
# 428            Lao PDR  2020         -0.049231         0.252173
# 430           Malaysia  2020          0.031569         0.331578
# 429            Myanmar  2020         -0.087099         0.219891
# 431        Philippines  2020         -0.042787         0.276984
# 432          Singapore  2020         -0.002454         0.744343
# 433           Thailand  2020          0.041921         0.344139
# 440     United Kingdom  2020          0.128604         0.610450
# 441      United States  2020          0.038932         0.656155
# 434           Viet Nam  2020          0.039363         0.307277
#
#      economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 425           0.568046             0.664785                0.405357  0.404785
# 426           0.232732             0.356424                0.451903  0.393905
# 435           0.594394             0.828305                0.390243  0.433494
# 436           0.572378             0.719387                0.284056  0.396667
# 437           0.587579             0.803963                0.279503  0.346770
# 427           0.385226             0.444347                0.467249  0.517932
# 439           0.422401             0.586826                0.336569  0.441074
# 438           0.640483             0.777122                0.469624  0.519501
# 428           0.330335             0.388682                0.554204  0.393777
# 430           0.589838             0.583601                0.365074  0.442960
# 429           0.267386             0.332527                0.556425  0.565127
# 431           0.320308             0.407199                0.428664  0.492328
# 432           0.777758             0.889685                0.334111  0.538327
# 433           0.591123             0.461587                0.479188  0.457570
# 440           0.685835             0.785403                0.280630  0.389994
# 441           0.618504             0.746137                0.424324  0.481034
# 434           0.462728             0.467515                0.553681  0.490791
#
#      foodvulnerability  habitatvulnerability  healthvulnerability  \
# 425           0.423695              0.538383             0.276822
# 426           0.588210              0.532453             0.585342
# 435           0.237562              0.512965             0.162663
# 436           0.307036              0.405312             0.134732
# 437           0.195457              0.374766             0.119480
# 427           0.543020              0.535990             0.413897
# 439           0.308011              0.394294             0.149182
# 438           0.241484              0.524612             0.111801
# 428           0.572733              0.522010             0.485234
# 430           0.446388              0.508736             0.314664
# 429           0.542253              0.504885             0.731873
# 431           0.519137              0.565115             0.382895
# 432           0.268209              0.450547             0.225824
# 433           0.437390              0.378567             0.383287
# 440           0.214557              0.412822             0.130113
# 441           0.348416              0.450501             0.131986
# 434           0.498739              0.430839             0.352048
#
#      watervulnerability  overallvulnerability  GDPPerCapita  \
# 425            0.287611              0.068319  27442.953830
# 426            0.551271              0.047935   1543.669258
# 435            0.203242             -0.036343  43258.263870
# 436            0.302513             -0.043354  39037.122630
# 437            0.378300             -0.024704  46252.689300
# 427            0.429491             -0.003367   3869.588427
# 439            0.306758             -0.032914  31769.965870
# 438            0.378262              0.009184  40193.252440
# 428            0.439536              0.051765   2629.714583
# 430            0.289965             -0.029621  10412.348980
# 429            0.392773              0.065775   1467.604281
# 431            0.504229              0.002623   3298.829586
# 432            0.485130              0.209982  59797.752180
# 433            0.442124             -0.010085   7186.874092
# 440            0.356954             -0.045503  41059.168810
# 441            0.292796              0.034683  63206.521080
# 434            0.477972              0.016484   2785.724161
#
#      PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 425                             1.217503                             -0.932221
# 426                            22.379226                             -1.358499
# 435                             1.794943                              1.476175
# 436                             1.596840                              1.069430
# 437                             0.735310                              1.377576
# 427                            13.703935                              0.099676
# 439                             1.987092                              1.057024
# 438                             1.060732                              0.987699
# 428                            16.208961                             -1.795886
# 430                             8.194521                             -0.148041
# 429                            21.979641                             -0.944312
# 431                            10.184808                             -0.103621
# 432                             0.032403                             -0.202116
# 433                             8.631140                             -0.809891
# 440                             0.581796                              1.246781
# 441                             0.929077                              0.868937
# 434                            14.853162                             -1.380470

# %%
df_2020_ave = df_2020.copy()

# %% [markdown]
# # Missing Values for Public Voice and Government Accountability
# Missing values are in the years 1995, 1997, 1999, and 2001 for the variable 'publicvoiceandgovaccountabilityindex' for all countries. The method for preprocessing is similar to how imputation was done for the missing values in 2020.

# %% [markdown]
# ## 1997 Value
# - The mean of 1996 and 1998 will be assigned to the 1997 value

# %%
#store years needed in a list
col = [1996, 1997, 1998]

#create a dataframe per country that filters it out on the years that we need
df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
df_france = df[df.Country == 'France'][df['Year'].isin(col)]
df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_france = df[df.Country == 'France'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3516544877.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]

# %%
#null value can be seen in last column of the dataframe
df_thailand
# Out:
#      Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 25  Thailand  1996          0.018361         0.203208           0.430365
# 42  Thailand  1997          0.025904         0.210615           0.430365
# 59  Thailand  1998          0.037259         0.223940           0.430365
#
#     governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 25             0.534232                0.488919   0.45757           0.504100
# 42             0.547117                0.496795   0.45757           0.501438
# 59             0.560002                0.502086   0.45757           0.501220
#
#     habitatvulnerability  healthvulnerability  watervulnerability  \
# 25              0.355530             0.442486            0.435608
# 42              0.354001             0.426732            0.435608
# 59              0.352561             0.424575            0.436078
#
#     overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 25             -0.017631   3043.980314                             9.063416
# 42             -0.020449   2468.184730                             9.064902
# 59             -0.022189   1845.828870                            10.259227
#
#     publicvoiceandgovaccountabilityindex
# 25                              0.310659
# 42                                   NaN
# 59                              0.382474

# %%
#create list to store variable with missing value
col = ['publicvoiceandgovaccountabilityindex']

#fill null values with the mean per column in col for each filtered country dataframe
df_brunei[col] = df_brunei[col].fillna(df_brunei[col].mean())
df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_france[col] = df_france[col].fillna(df_france[col].mean())
df_germany[col] = df_germany[col].fillna(df_germany[col].mean())
df_indonesia[col] = df_indonesia[col].fillna(df_indonesia[col].mean())
df_italy[col] = df_italy[col].fillna(df_italy[col].mean())
df_japan[col] = df_japan[col].fillna(df_japan[col].mean())
df_lao[col] = df_lao[col].fillna(df_lao[col].mean())
df_malaysia[col] = df_malaysia[col].fillna(df_malaysia[col].mean())
df_myanmar[col] = df_myanmar[col].fillna(df_myanmar[col].mean())
df_philippines[col] = df_philippines[col].fillna(df_philippines[col].mean())
df_singapore[col] = df_singapore[col].fillna(df_singapore[col].mean())
df_thailand[col] = df_thailand[col].fillna(df_thailand[col].mean())
df_uk[col] = df_uk[col].fillna(df_uk[col].mean())
df_usa[col] = df_usa[col].fillna(df_usa[col].mean())
df_vietnam[col] = df_vietnam[col].fillna(df_vietnam[col].mean())

#drop all rows in the dataframe that do not contain year 1997
df_brunei = df_brunei[df_brunei['Year'].isin([1997])]
df_cambodia = df_cambodia[df_cambodia['Year'].isin([1997])]
df_canada = df_canada[df_canada['Year'].isin([1997])]
df_france = df_france[df_france['Year'].isin([1997])]
df_germany = df_germany[df_germany['Year'].isin([1997])]
df_indonesia = df_indonesia[df_indonesia['Year'].isin([1997])]
df_italy = df_italy[df_italy['Year'].isin([1997])]
df_japan = df_japan[df_japan['Year'].isin([1997])]
df_lao = df_lao[df_lao['Year'].isin([1997])]
df_malaysia = df_malaysia[df_malaysia['Year'].isin([1997])]
df_myanmar = df_myanmar[df_myanmar['Year'].isin([1997])]
df_philippines = df_philippines[df_philippines['Year'].isin([1997])]
df_singapore = df_singapore[df_singapore['Year'].isin([1997])]
df_thailand = df_thailand[df_thailand['Year'].isin([1997])]
df_uk = df_uk[df_uk['Year'].isin([1997])]
df_usa = df_usa[df_usa['Year'].isin([1997])]
df_vietnam = df_vietnam[df_vietnam['Year'].isin([1997])]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/4060626266.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())

# %%
#make a copy of main dataframe
copy = df_2020.copy()
#drop 1997 year with missing value
copy = copy[~copy['Year'].isin([1997])]

# %%
#store all country dataframes with imputed values in a list
frames = [df_brunei, df_cambodia, df_canada, df_france, df_germany, df_indonesia, df_italy, 
            df_japan, df_lao, df_malaysia, df_myanmar, df_philippines, 
            df_singapore, df_thailand, df_uk, df_usa, df_vietnam, copy]

#concatenate the list with the original dataframe
#the main dataframe is now df_1997
df_1997 = pd.concat(frames)

# %%
#no more null values
df_1997[df_1997.Year==1997]
# Out:
#               Country  Year  overallreadiness  socialreadiness  \
# 34  Brunei Darussalam  1997         -0.184034         0.179691
# 35           Cambodia  1997         -0.062319         0.196205
# 44             Canada  1997          0.140332         0.473758
# 45             France  1997          0.142177         0.563769
# 46            Germany  1997          0.167734         0.566376
# 36          Indonesia  1997          0.002762         0.241115
# 48              Italy  1997          0.023502         0.393457
# 47              Japan  1997          0.159615         0.619438
# 37            Lao PDR  1997         -0.042002         0.199081
# 39           Malaysia  1997         -0.004680         0.178431
# 38            Myanmar  1997         -0.069758         0.111524
# 40        Philippines  1997         -0.020699         0.198130
# 41          Singapore  1997          0.065867         0.411478
# 42           Thailand  1997          0.025904         0.210615
# 49     United Kingdom  1997          0.172042         0.527930
# 50      United States  1997          0.140116         0.564317
# 43           Viet Nam  1997          0.000230         0.206873
#
#     economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 34           0.522559             0.669696                0.396842  0.404785
# 35           0.313859             0.323651                0.462007  0.393905
# 44           0.485895             0.828824                0.402758  0.433494
# 45           0.455845             0.732598                0.294394  0.396667
# 46           0.475101             0.820609                0.286985  0.346770
# 36           0.503790             0.345157                0.497770  0.517932
# 48           0.359081             0.666918                0.350736  0.441074
# 47           0.503401             0.723191                0.474244  0.519501
# 37           0.330295             0.375416                0.557446  0.393777
# 39           0.398176             0.594373                0.367623  0.442960
# 38           0.492703             0.204772                0.555430  0.565127
# 40           0.313276             0.481725                0.433735  0.492328
# 41           0.516627             0.839001                0.345598  0.538327
# 42           0.430365             0.547117                0.496795  0.457570
# 49           0.479380             0.845882                0.285221  0.389994
# 50           0.522559             0.790694                0.432029  0.481034
# 43           0.383880             0.442146                0.561250  0.490791
#
#     foodvulnerability  habitatvulnerability  healthvulnerability  \
# 34           0.432365              0.623023             0.375111
# 35           0.640027              0.569429             0.507587
# 44           0.240194              0.504097             0.291677
# 45           0.311808              0.390765             0.252634
# 46           0.219233              0.364166             0.244853
# 36           0.582163              0.526033             0.482700
# 48           0.318768              0.384409             0.205594
# 47           0.269828              0.468585             0.140744
# 37           0.643945              0.554078             0.627740
# 39           0.496911              0.515237             0.384620
# 38           0.566616              0.595606             0.675962
# 40           0.521977              0.613334             0.477660
# 41           0.270069              0.457539             0.304045
# 42           0.501438              0.354001             0.426732
# 49           0.197089              0.401170             0.119185
# 50           0.356300              0.450275             0.272064
# 43           0.530217              0.506215             0.472505
#
#     watervulnerability  overallvulnerability  GDPPerCapita  \
# 34            0.285724              0.103758  16660.147630
# 35            0.566929              0.065575    304.764769
# 44            0.204685             -0.092429  21901.562850
# 45            0.306370             -0.107873  24228.946390
# 46            0.402039             -0.097065  26964.049470
# 36            0.418619              0.007724   1063.712376
# 48            0.329804             -0.080340  21829.345820
# 47            0.382370             -0.046684  35638.231960
# 37            0.461857              0.086174    345.921844
# 39            0.277320             -0.066244   4637.865661
# 38            0.402766              0.074128    125.103689
# 40            0.519270              0.025932   1288.580731
# 41            0.549206              0.045882  26375.971950
# 42            0.435608             -0.020449   2468.184730
# 49            0.360162             -0.136896  26742.984850
# 50            0.276116             -0.040973  31459.138980
# 43            0.467512              0.036434    348.017407
#
#     PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 34                             1.227344                             -0.686584
# 35                            44.447213                             -0.782469
# 44                             2.139498                              1.558874
# 45                             2.344256                              1.241470
# 46                             1.031385                              1.310391
# 36                            16.092110                             -0.974080
# 48                             2.861912                              1.096633
# 47                             1.527913                              1.009858
# 37                            51.852706                             -1.219524
# 39                            11.101333                             -0.301512
# 38                                  NaN                             -1.904177
# 40                            16.449102                              0.338720
# 41                             0.132917                              0.126158
# 42                             9.064902                              0.346566
# 49                             0.969677                              1.233798
# 50                             1.336912                              1.342769
# 43                            25.771707                             -1.217604

# %% [markdown]
# ## 1999 Value
# - The mean of 1998 and 2000 will be assigned to 1999 value

# %%
#store years needed in a list
col = [1998, 1999, 2000]

#create a dataframe per country that filters it out on the years that we need
df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
df_france = df[df.Country == 'France'][df['Year'].isin(col)]
df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_france = df[df.Country == 'France'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3418468771.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]

# %%
#create list to store variable with missing value
col = ['publicvoiceandgovaccountabilityindex']

#fill null values with the mean per column in col for each filtered country dataframe
df_brunei[col] = df_brunei[col].fillna(df_brunei[col].mean())
df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_france[col] = df_france[col].fillna(df_france[col].mean())
df_germany[col] = df_germany[col].fillna(df_germany[col].mean())
df_indonesia[col] = df_indonesia[col].fillna(df_indonesia[col].mean())
df_italy[col] = df_italy[col].fillna(df_italy[col].mean())
df_japan[col] = df_japan[col].fillna(df_japan[col].mean())
df_lao[col] = df_lao[col].fillna(df_lao[col].mean())
df_malaysia[col] = df_malaysia[col].fillna(df_malaysia[col].mean())
df_myanmar[col] = df_myanmar[col].fillna(df_myanmar[col].mean())
df_philippines[col] = df_philippines[col].fillna(df_philippines[col].mean())
df_singapore[col] = df_singapore[col].fillna(df_singapore[col].mean())
df_thailand[col] = df_thailand[col].fillna(df_thailand[col].mean())
df_uk[col] = df_uk[col].fillna(df_uk[col].mean())
df_usa[col] = df_usa[col].fillna(df_usa[col].mean())
df_vietnam[col] = df_vietnam[col].fillna(df_vietnam[col].mean())

yr = [1999]

#only keep the rows that contain value in list yr
df_brunei = df_brunei[df_brunei['Year'].isin(yr)]
df_cambodia = df_cambodia[df_cambodia['Year'].isin(yr)]
df_canada = df_canada[df_canada['Year'].isin(yr)]
df_france = df_france[df_france['Year'].isin(yr)]
df_germany = df_germany[df_germany['Year'].isin(yr)]
df_indonesia = df_indonesia[df_indonesia['Year'].isin(yr)]
df_italy = df_italy[df_italy['Year'].isin(yr)]
df_japan = df_japan[df_japan['Year'].isin(yr)]
df_lao = df_lao[df_lao['Year'].isin(yr)]
df_malaysia = df_malaysia[df_malaysia['Year'].isin(yr)]
df_myanmar = df_myanmar[df_myanmar['Year'].isin(yr)]
df_philippines = df_philippines[df_philippines['Year'].isin(yr)]
df_singapore = df_singapore[df_singapore['Year'].isin(yr)]
df_thailand = df_thailand[df_thailand['Year'].isin(yr)]
df_uk = df_uk[df_uk['Year'].isin(yr)]
df_usa = df_usa[df_usa['Year'].isin(yr)]
df_vietnam = df_vietnam[df_vietnam['Year'].isin(yr)]

# %%
df_brunei
# Out:
#               Country  Year  overallreadiness  socialreadiness  \
# 68  Brunei Darussalam  1999         -0.188088         0.189581
#
#     economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 68           0.522559             0.652525                0.398022  0.404785
#
#     foodvulnerability  habitatvulnerability  healthvulnerability  \
# 68           0.439737              0.619769             0.332219
#
#     watervulnerability  overallvulnerability  GDPPerCapita  \
# 68             0.28601              0.098641   14101.17285
#
#     PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 68                              1.23498                             -0.718058

# %%
copy = df_1997.copy()
copy = copy[~copy['Year'].isin([1999])]

# %%
frames = [df_brunei, df_cambodia, df_canada, df_france, df_germany, df_indonesia, df_italy, 
            df_japan, df_lao, df_malaysia, df_myanmar, df_philippines, 
            df_singapore, df_thailand, df_uk, df_usa, df_vietnam, copy]

#new main dataframe to use for the next imputation needed
df_1999 = pd.concat(frames)

# %%
#no more null values for 1999
df_1999[df_1999.Year==1999]
# Out:
#               Country  Year  overallreadiness  socialreadiness  \
# 68  Brunei Darussalam  1999         -0.188088         0.189581
# 69           Cambodia  1999         -0.058051         0.197794
# 78             Canada  1999          0.132907         0.485253
# 79             France  1999          0.134383         0.571396
# 80            Germany  1999          0.166663         0.584886
# 70          Indonesia  1999         -0.000433         0.251843
# 82              Italy  1999          0.019466         0.406359
# 81              Japan  1999          0.164995         0.634166
# 71            Lao PDR  1999         -0.052264         0.203275
# 73           Malaysia  1999         -0.000652         0.206460
# 72            Myanmar  1999         -0.071704         0.118190
# 74        Philippines  1999         -0.030639         0.201060
# 75          Singapore  1999          0.079466         0.457900
# 76           Thailand  1999          0.040306         0.234374
# 83     United Kingdom  1999          0.176715         0.557876
# 84      United States  1999          0.133608         0.576340
# 77           Viet Nam  1999         -0.000659         0.211661
#
#     economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 68           0.522559             0.652525                0.398022  0.404785
# 69           0.313859             0.336689                0.461355  0.393905
# 78           0.485895             0.831835                0.402386  0.433494
# 79           0.455845             0.731132                0.293283  0.396667
# 80           0.475101             0.823519                0.286312  0.346770
# 70           0.503790             0.315569                0.514843  0.517932
# 82           0.359081             0.666649                0.344819  0.441074
# 81           0.503401             0.727165                0.474816  0.519501
# 71           0.330295             0.342749                0.557446  0.393777
# 73           0.398176             0.571330                0.367763  0.442960
# 72           0.492703             0.193967                0.555568  0.565127
# 74           0.313276             0.449253                0.440753  0.492328
# 75           0.516627             0.843010                0.347410  0.538327
# 76           0.430365             0.563282                0.511244  0.457570
# 83           0.479380             0.849642                0.289079  0.389994
# 84           0.522559             0.802711                0.432503  0.481034
# 77           0.383880             0.437278                0.558681  0.490791
#
#     foodvulnerability  habitatvulnerability  healthvulnerability  \
# 68           0.439737              0.619769             0.332219
# 69           0.654288              0.560058             0.522291
# 78           0.236701              0.502342             0.291677
# 79           0.309481              0.391716             0.161739
# 80           0.216293              0.365580             0.243677
# 70           0.564301              0.542965             0.482700
# 82           0.317690              0.386384             0.203453
# 81           0.271725              0.469231             0.133766
# 71           0.640585              0.554960             0.622633
# 73           0.492363              0.514730             0.384196
# 72           0.570570              0.593192             0.675928
# 74           0.519070              0.607374             0.437228
# 75           0.269083              0.449931             0.240470
# 76           0.493062              0.351266             0.423613
# 83           0.191154              0.400418             0.258884
# 84           0.353351              0.450167             0.270652
# 77           0.547084              0.496049             0.473420
#
#     watervulnerability  overallvulnerability  GDPPerCapita  \
# 68            0.286010              0.098641  14101.172850
# 69            0.566930              0.072530    295.903178
# 78            0.204677             -0.084746  22315.246670
# 79            0.306998             -0.116486  24681.537010
# 80            0.399105             -0.092501  26734.942540
# 70            0.419532              0.007230    671.098610
# 82            0.328729             -0.075999  22005.054540
# 81            0.381604             -0.046851  36610.168320
# 71            0.463654              0.085539    277.810213
# 73            0.279199             -0.068883   3492.670125
# 72            0.402935              0.072940    122.210639
# 74            0.519062              0.018404   1122.032017
# 75            0.549240              0.036316  21796.084440
# 76            0.436549             -0.021182   2033.258009
# 83            0.360337             -0.110019  28726.857210
# 84            0.278543             -0.031148  34513.561500
# 77            0.469267              0.035071    362.919503
#
#     PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 68                             1.234980                             -0.718058
# 69                            40.903853                             -0.798124
# 78                             2.196213                              1.541689
# 79                             2.236261                              1.177385
# 80                             0.958397                              1.303345
# 70                            19.612676                             -0.647323
# 82                             2.722232                              1.052347
# 81                             1.576060                              0.952437
# 71                            34.311979                             -1.323862
# 73                            10.842388                             -0.421519
# 72                                  NaN                             -1.979124
# 74                            15.194355                              0.326038
# 75                             0.111246                              0.121499
# 76                             8.892995                              0.425138
# 83                             0.876609                              1.259273
# 84                             1.151183                              1.323522
# 77                            25.434438                             -1.293006

# %% [markdown]
# ## 2001 Value
# - The mean of 2000 and 2002 will be assigned to 2001 value

# %%
col = [2000, 2001, 2002]

df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
df_france = df[df.Country == 'France'][df['Year'].isin(col)]
df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_france = df[df.Country == 'France'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2063651355.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]

# %%
col = ['publicvoiceandgovaccountabilityindex']

df_brunei[col] = df_brunei[col].fillna(df_brunei[col].mean())
df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_france[col] = df_france[col].fillna(df_france[col].mean())
df_germany[col] = df_germany[col].fillna(df_germany[col].mean())
df_indonesia[col] = df_indonesia[col].fillna(df_indonesia[col].mean())
df_italy[col] = df_italy[col].fillna(df_italy[col].mean())
df_japan[col] = df_japan[col].fillna(df_japan[col].mean())
df_lao[col] = df_lao[col].fillna(df_lao[col].mean())
df_malaysia[col] = df_malaysia[col].fillna(df_malaysia[col].mean())
df_myanmar[col] = df_myanmar[col].fillna(df_myanmar[col].mean())
df_philippines[col] = df_philippines[col].fillna(df_philippines[col].mean())
df_singapore[col] = df_singapore[col].fillna(df_singapore[col].mean())
df_thailand[col] = df_thailand[col].fillna(df_thailand[col].mean())
df_uk[col] = df_uk[col].fillna(df_uk[col].mean())
df_usa[col] = df_usa[col].fillna(df_usa[col].mean())
df_vietnam[col] = df_vietnam[col].fillna(df_vietnam[col].mean())

yr = [2001]

df_brunei = df_brunei[df_brunei['Year'].isin(yr)]
df_cambodia = df_cambodia[df_cambodia['Year'].isin(yr)]
df_canada = df_canada[df_canada['Year'].isin(yr)]
df_france = df_france[df_france['Year'].isin(yr)]
df_germany = df_germany[df_germany['Year'].isin(yr)]
df_indonesia = df_indonesia[df_indonesia['Year'].isin(yr)]
df_italy = df_italy[df_italy['Year'].isin(yr)]
df_japan = df_japan[df_japan['Year'].isin(yr)]
df_lao = df_lao[df_lao['Year'].isin(yr)]
df_malaysia = df_malaysia[df_malaysia['Year'].isin(yr)]
df_myanmar = df_myanmar[df_myanmar['Year'].isin(yr)]
df_philippines = df_philippines[df_philippines['Year'].isin(yr)]
df_singapore = df_singapore[df_singapore['Year'].isin(yr)]
df_thailand = df_thailand[df_thailand['Year'].isin(yr)]
df_uk = df_uk[df_uk['Year'].isin(yr)]
df_usa = df_usa[df_usa['Year'].isin(yr)]
df_vietnam = df_vietnam[df_vietnam['Year'].isin(yr)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/3977954969.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa[col] = df_usa[col].fillna(df_usa[col].mean())

# %%
copy = df_1999.copy()
copy = copy[~copy['Year'].isin([2001])]

# %%
frames = [df_brunei, df_cambodia, df_canada, df_france, df_germany, df_indonesia, df_italy, 
            df_japan, df_lao, df_malaysia, df_myanmar, df_philippines, 
            df_singapore, df_thailand, df_uk, df_usa, df_vietnam, copy]

df_2001 = pd.concat(frames)

# %%
df_2001.isnull().sum()
# Out:
# Country                                  0
# Year                                     0
# overallreadiness                         0
# socialreadiness                          0
# economicreadiness                        0
# governmentreadiness                      0
# ecosystemvulnerability                   0
# exposure                                 0
# foodvulnerability                        0
# habitatvulnerability                     0
# healthvulnerability                      0
# watervulnerability                       0
# overallvulnerability                     0
# GDPPerCapita                             0
# PercGDPContributionOfAgriForestFish     11
# publicvoiceandgovaccountabilityindex    17
# dtype: int64

# %%
#no more null values for variable publicvoiceandgovaccountabilityindex for year 2001
df_2001[df_2001.Year==2001]
# Out:
#                Country  Year  overallreadiness  socialreadiness  \
# 102  Brunei Darussalam  2001         -0.199402         0.208591
# 103           Cambodia  2001         -0.053919         0.198676
# 112             Canada  2001          0.128461         0.503353
# 113             France  2001          0.124302         0.586952
# 114            Germany  2001          0.163859         0.605915
# 104          Indonesia  2001         -0.004899         0.251628
# 116              Italy  2001          0.025904         0.464333
# 115              Japan  2001          0.158576         0.657532
# 105            Lao PDR  2001         -0.060833         0.209351
# 107           Malaysia  2001          0.008150         0.238274
# 106            Myanmar  2001         -0.072471         0.127808
# 108        Philippines  2001         -0.042471         0.207829
# 109          Singapore  2001          0.092734         0.533179
# 110           Thailand  2001          0.037948         0.249308
# 117     United Kingdom  2001          0.160272         0.572441
# 118      United States  2001          0.121489         0.583976
# 111           Viet Nam  2001         -0.006295         0.206694
#
#      economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 102           0.522559             0.654014                0.399268  0.404785
# 103           0.313859             0.350866                0.461355  0.393905
# 112           0.485895             0.834081                0.401290  0.433494
# 113           0.455845             0.730892                0.293040  0.396667
# 114           0.475101             0.823881                0.286203  0.346770
# 104           0.503790             0.309122                0.514994  0.517932
# 116           0.359081             0.662840                0.344524  0.441074
# 115           0.503401             0.715161                0.474548  0.519501
# 105           0.330295             0.314193                0.557446  0.393777
# 107           0.398176             0.581623                0.365670  0.442960
# 106           0.492703             0.185404                0.555568  0.565127
# 108           0.313276             0.410600                0.441485  0.492328
# 109           0.516627             0.852162                0.347409  0.538327
# 110           0.430365             0.551808                0.512255  0.457570
# 117           0.479380             0.833420                0.288718  0.389994
# 118           0.522559             0.796079                0.432132  0.481034
# 111           0.383880             0.429530                0.558681  0.490791
#
#      foodvulnerability  habitatvulnerability  healthvulnerability  \
# 102           0.440782              0.597948             0.285691
# 103           0.648433              0.550331             0.546692
# 112           0.238162              0.500228             0.154652
# 113           0.306271              0.392851             0.148431
# 114           0.210363              0.367805             0.122500
# 104           0.528564              0.520934             0.483197
# 116           0.317112              0.388665             0.238406
# 115           0.261881              0.474386             0.126737
# 105           0.626574              0.554661             0.682399
# 107           0.483451              0.510744             0.356133
# 106           0.574405              0.566387             0.687970
# 108           0.512036              0.605177             0.417039
# 109           0.267960              0.448300             0.235425
# 110           0.474078              0.351164             0.421271
# 117           0.190732              0.399451             0.132568
# 118           0.351016              0.447825             0.270455
# 111           0.520657              0.480169             0.455318
#
#      watervulnerability  overallvulnerability  GDPPerCapita  \
# 102            0.286296              0.099952  16472.003290
# 103            0.566121              0.072480    321.150224
# 112            0.204655             -0.100547  23822.060120
# 113            0.307612             -0.108688  22452.982380
# 114            0.396171             -0.106913  23628.327210
# 104            0.420446             -0.000067    748.257609
# 116            0.326660             -0.062266  20500.954400
# 115            0.380838             -0.042018  34406.182460
# 105            0.462371              0.095100    326.941787
# 107            0.280885             -0.070648   3913.429386
# 106            0.403105              0.070121    131.715307
# 108            0.518697              0.013294    990.565991
# 109            0.549274              0.044995  21700.020050
# 110            0.437489             -0.024000   1893.264239
# 117            0.360513             -0.119726  27806.448820
# 118            0.280971             -0.023205  37133.242810
# 111            0.471021              0.025732    404.807861
#
#      PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 102                             1.134567                             -0.773252
# 103                            34.320300                             -0.760541
# 112                             2.117891                              1.515510
# 113                             2.107008                              1.168664
# 114                             1.083432                              1.364416
# 104                            15.994918                             -0.271040
# 116                             2.489631                              1.039686
# 115                             1.367506                              0.986279
# 105                            32.683193                             -1.540049
# 107                             8.010971                             -0.457006
# 106                            57.140091                             -2.026318
# 108                            13.302809                              0.198484
# 109                             0.082357                              0.094558
# 110                             8.579287                              0.394660
# 117                             0.782121                              1.303346
# 118                             1.129326                              1.327368
# 111                            23.241048                             -1.343559

# %% [markdown]
# ## 1995 Value
# - Since 1995 is the oldest year in the dataset, the 1996 value will be assigned to the 1995 value for each country.

# %%
col = [1995, 1996]

df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
df_france = df[df.Country == 'France'][df['Year'].isin(col)]
df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_brunei = df[df.Country == 'Brunei Darussalam'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cambodia = df[df.Country == 'Cambodia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df[df.Country == 'Canada'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_france = df[df.Country == 'France'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_germany = df[df.Country == 'Germany'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_indonesia = df[df.Country == 'Indonesia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_italy = df[df.Country == 'Italy'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_japan = df[df.Country == 'Japan'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_lao = df[df.Country == 'Lao PDR'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_malaysia = df[df.Country == 'Malaysia'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df[df.Country == 'Myanmar'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_philippines = df[df.Country == 'Philippines'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_singapore = df[df.Country == 'Singapore'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_thailand = df[df.Country == 'Thailand'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_uk = df[df.Country == 'United Kingdom'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df[df.Country == 'United States'][df['Year'].isin(col)]
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2621414512.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_vietnam = df[df.Country == 'Viet Nam'][df['Year'].isin(col)]

# %%
col = ['publicvoiceandgovaccountabilityindex']

df_brunei[col] = df_brunei[col].fillna(df_brunei[col].mean())
df_cambodia[col] = df_cambodia[col].fillna(df_cambodia[col].mean())
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_france[col] = df_france[col].fillna(df_france[col].mean())
df_germany[col] = df_germany[col].fillna(df_germany[col].mean())
df_indonesia[col] = df_indonesia[col].fillna(df_indonesia[col].mean())
df_italy[col] = df_italy[col].fillna(df_italy[col].mean())
df_japan[col] = df_japan[col].fillna(df_japan[col].mean())
df_lao[col] = df_lao[col].fillna(df_lao[col].mean())
df_malaysia[col] = df_malaysia[col].fillna(df_malaysia[col].mean())
df_myanmar[col] = df_myanmar[col].fillna(df_myanmar[col].mean())
df_philippines[col] = df_philippines[col].fillna(df_philippines[col].mean())
df_singapore[col] = df_singapore[col].fillna(df_singapore[col].mean())
df_thailand[col] = df_thailand[col].fillna(df_thailand[col].mean())
df_uk[col] = df_uk[col].fillna(df_uk[col].mean())
df_usa[col] = df_usa[col].fillna(df_usa[col].mean())
df_vietnam[col] = df_vietnam[col].fillna(df_vietnam[col].mean())

yr = [1995]

df_brunei = df_brunei[df_brunei['Year'].isin(yr)]
df_cambodia = df_cambodia[df_cambodia['Year'].isin(yr)]
df_canada = df_canada[df_canada['Year'].isin(yr)]
df_france = df_france[df_france['Year'].isin(yr)]
df_germany = df_germany[df_germany['Year'].isin(yr)]
df_indonesia = df_indonesia[df_indonesia['Year'].isin(yr)]
df_italy = df_italy[df_italy['Year'].isin(yr)]
df_japan = df_japan[df_japan['Year'].isin(yr)]
df_lao = df_lao[df_lao['Year'].isin(yr)]
df_malaysia = df_malaysia[df_malaysia['Year'].isin(yr)]
df_myanmar = df_myanmar[df_myanmar['Year'].isin(yr)]
df_philippines = df_philippines[df_philippines['Year'].isin(yr)]
df_singapore = df_singapore[df_singapore['Year'].isin(yr)]
df_thailand = df_thailand[df_thailand['Year'].isin(yr)]
df_uk = df_uk[df_uk['Year'].isin(yr)]
df_usa = df_usa[df_usa['Year'].isin(yr)]
df_vietnam = df_vietnam[df_vietnam['Year'].isin(yr)]

# %%
copy = df_2001.copy()
copy = copy[~copy['Year'].isin([1995])]

# %%
frames = [df_brunei, df_cambodia, df_canada, df_france, df_germany, df_indonesia, df_italy, 
            df_japan, df_lao, df_malaysia, df_myanmar, df_philippines, 
            df_singapore, df_thailand, df_uk, df_usa, df_vietnam, copy]

df_pubvoice_complete = pd.concat(frames)

# %%
#no more null values for variable publicvoiceandgovaccountabilityindex for year 1995
df_pubvoice_complete[df_pubvoice_complete.Year==1995]
# Out:
#               Country  Year  overallreadiness  socialreadiness  \
# 0   Brunei Darussalam  1995         -0.178337         0.174853
# 1            Cambodia  1995         -0.059828         0.196209
# 10             Canada  1995          0.143769         0.459899
# 11             France  1995          0.144454         0.542928
# 12            Germany  1995          0.169407         0.556133
# 2           Indonesia  1995          0.015053         0.233235
# 14              Italy  1995          0.029601         0.386917
# 13              Japan  1995          0.164042         0.603849
# 3             Lao PDR  1995         -0.040706         0.197401
# 5            Malaysia  1995          0.005321         0.162479
# 4             Myanmar  1995         -0.069966         0.107750
# 6         Philippines  1995         -0.023954         0.196803
# 7           Singapore  1995          0.063319         0.342230
# 8            Thailand  1995          0.019498         0.200351
# 15     United Kingdom  1995          0.177075         0.513785
# 16      United States  1995          0.150419         0.559863
# 9            Viet Nam  1995          0.000692         0.199364
#
#     economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 0            0.522559             0.691582                0.399451  0.404785
# 1            0.313859             0.330263                0.463645  0.393905
# 10           0.485895             0.827835                0.400140  0.433494
# 11           0.455845             0.738754                0.291479  0.396667
# 12           0.475101             0.820803                0.280313  0.346770
# 2            0.503790             0.381178                0.475409  0.517932
# 14           0.359081             0.669978                0.346409  0.441074
# 13           0.503401             0.727296                0.474524  0.519501
# 3            0.330295             0.378320                0.557446  0.393777
# 5            0.398176             0.615731                0.369050  0.442960
# 4            0.492703             0.206757                0.559146  0.565127
# 6            0.313276             0.468966                0.429961  0.492328
# 7            0.516627             0.840669                0.349677  0.538327
# 8            0.430365             0.534232                0.480401  0.457570
# 15           0.479380             0.839046                0.286945  0.389994
# 16           0.522559             0.786576                0.428386  0.481034
# 9            0.383880             0.447268                0.558990  0.490791
#
#     foodvulnerability  habitatvulnerability  healthvulnerability  \
# 0            0.434201              0.625081             0.396556
# 1            0.637270              0.571884             0.507440
# 10           0.243380              0.504988             0.291677
# 11           0.319083              0.389452             0.253146
# 12           0.221775              0.362966             0.245788
# 2            0.602365              0.532567             0.482700
# 14           0.319228              0.382740             0.207904
# 13           0.271064              0.468577             0.144273
# 3            0.646768              0.551481             0.615999
# 5            0.505651              0.514855             0.387670
# 4            0.567118              0.598676             0.675996
# 6            0.525679              0.617155             0.477801
# 7            0.270960              0.458100             0.304045
# 8            0.505314              0.357334             0.427541
# 15           0.197825              0.401152             0.261049
# 16           0.357600              0.449454             0.141045
# 9            0.542331              0.508015             0.472505
#
#     watervulnerability  overallvulnerability  GDPPerCapita  \
# 0             0.285724              0.108407  15933.452830
# 1             0.566929              0.065538    322.931575
# 10            0.204685             -0.097689  20613.787880
# 11            0.306370             -0.112213  26890.217620
# 12            0.402039             -0.101326  31658.349380
# 2             0.418619              0.010084   1026.393436
# 14            0.329804             -0.085755  20664.552270
# 13            0.382370             -0.051355  44197.619100
# 3             0.461857              0.083271    363.880052
# 5             0.277320             -0.071337   4329.707998
# 4             0.402766              0.075015    111.140814
# 6             0.519270              0.025944   1212.944437
# 7             0.549206              0.033276  24914.411260
# 8             0.435608             -0.022447   2846.586834
# 15            0.360162             -0.120684  23206.568560
# 16            0.276116             -0.072398  28690.875700
# 9             0.467512              0.038032    276.812663
#
#     PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 0                              1.161528                             -0.649972
# 1                             47.724560                             -0.749472
# 10                                  NaN                              1.566336
# 11                             2.444772                              1.311158
# 12                             0.995456                              1.328895
# 2                             17.138346                             -0.923690
# 14                             2.977708                              1.129291
# 13                             1.645030                              1.072930
# 3                             42.226236                             -1.132530
# 5                             12.949437                             -0.181070
# 4                                   NaN                             -1.889918
# 6                             18.925146                              0.257728
# 7                              0.144862                              0.139816
# 8                              9.081225                              0.310659
# 15                             1.262968                              1.272319
# 16                                  NaN                              1.348661
# 9                             27.182689                             -1.087494

# %%
#only missing values left are for agriculture 
df_pubvoice_complete.isnull().sum()
# Out:
# Country                                  0
# Year                                     0
# overallreadiness                         0
# socialreadiness                          0
# economicreadiness                        0
# governmentreadiness                      0
# ecosystemvulnerability                   0
# exposure                                 0
# foodvulnerability                        0
# habitatvulnerability                     0
# healthvulnerability                      0
# watervulnerability                       0
# overallvulnerability                     0
# GDPPerCapita                             0
# PercGDPContributionOfAgriForestFish     11
# publicvoiceandgovaccountabilityindex     0
# dtype: int64

# %% [markdown]
# # Missing Values for Percent GDP Contribution of Agriculture, Forestry, and Fishing
# ***(Variable = PercGDPContributionOfAgriForestFish)***
#
# - The missing values are located in the following countries: Myanmar, Canada, and USA. Years of the missing values vary per country

# %% [markdown]
# ## For Myanmar
# -  The 2001  value of the variable for Myanmar will be assigned to the missing values from 1995 to 2000.

# %%
df_agri = df_pubvoice_complete.copy()

# %%
col = [1995, 1996, 1997, 1998, 1999, 2000, 2001]
df_myanmar = df_agri[df_agri.Country == 'Myanmar'][df_agri['Year'].isin(col)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/966687994.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_myanmar = df_agri[df_agri.Country == 'Myanmar'][df_agri['Year'].isin(col)]

# %%
#missing values can be seen in PercGDPContributionOfAgriForestFish
df_myanmar
# Out:
#      Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 4    Myanmar  1995         -0.069966         0.107750           0.492703
# 106  Myanmar  2001         -0.072471         0.127808           0.492703
# 72   Myanmar  1999         -0.071704         0.118190           0.492703
# 38   Myanmar  1997         -0.069758         0.111524           0.492703
# 21   Myanmar  1996         -0.069541         0.109629           0.492703
# 55   Myanmar  1998         -0.069982         0.113389           0.492703
# 89   Myanmar  2000         -0.073612         0.122993           0.492703
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 4               0.206757                0.559146  0.565127           0.567118
# 106             0.185404                0.555568  0.565127           0.574405
# 72              0.193967                0.555568  0.565127           0.570570
# 38              0.204772                0.555430  0.565127           0.566616
# 21              0.206757                0.555967  0.565127           0.566985
# 55              0.202786                0.555568  0.565127           0.568510
# 89              0.185148                0.555568  0.565127           0.572634
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 4                0.598676             0.675996            0.402766
# 106              0.566387             0.687970            0.403105
# 72               0.593192             0.675928            0.402935
# 38               0.595606             0.675962            0.402766
# 21               0.596843             0.675979            0.402766
# 55               0.594374             0.675945            0.402850
# 89               0.579385             0.675844            0.403020
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 4                0.075015    111.140814                                  NaN
# 106              0.070121    131.715307                            57.140091
# 72               0.072940    122.210639                                  NaN
# 38               0.074128    125.103689                                  NaN
# 21               0.074391    129.568938                                  NaN
# 55               0.073801    101.138952                                  NaN
# 89               0.070265    146.604579                                  NaN
#
#      publicvoiceandgovaccountabilityindex
# 4                               -1.889918
# 106                             -2.026318
# 72                              -1.979124
# 38                              -1.904177
# 21                              -1.889918
# 55                              -1.918437
# 89                              -2.039811

# %%
#fill missing values with 2001 value
df_myanmar['PercGDPContributionOfAgriForestFish'] = df_myanmar['PercGDPContributionOfAgriForestFish'].fillna(57.140091)
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/1903257096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_myanmar['PercGDPContributionOfAgriForestFish'] = df_myanmar['PercGDPContributionOfAgriForestFish'].fillna(57.140091)

# %%
#drop 2001 row
df_myanmar.drop(df_myanmar.index[df_myanmar['Year'] == 2001], inplace=True)
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/845359171.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_myanmar.drop(df_myanmar.index[df_myanmar['Year'] == 2001], inplace=True)

# %%
#dataframe for Myanmar is ready to concatenate with main df
df_myanmar
# Out:
#     Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 4   Myanmar  1995         -0.069966         0.107750           0.492703
# 72  Myanmar  1999         -0.071704         0.118190           0.492703
# 38  Myanmar  1997         -0.069758         0.111524           0.492703
# 21  Myanmar  1996         -0.069541         0.109629           0.492703
# 55  Myanmar  1998         -0.069982         0.113389           0.492703
# 89  Myanmar  2000         -0.073612         0.122993           0.492703
#
#     governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 4              0.206757                0.559146  0.565127           0.567118
# 72             0.193967                0.555568  0.565127           0.570570
# 38             0.204772                0.555430  0.565127           0.566616
# 21             0.206757                0.555967  0.565127           0.566985
# 55             0.202786                0.555568  0.565127           0.568510
# 89             0.185148                0.555568  0.565127           0.572634
#
#     habitatvulnerability  healthvulnerability  watervulnerability  \
# 4               0.598676             0.675996            0.402766
# 72              0.593192             0.675928            0.402935
# 38              0.595606             0.675962            0.402766
# 21              0.596843             0.675979            0.402766
# 55              0.594374             0.675945            0.402850
# 89              0.579385             0.675844            0.403020
#
#     overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 4               0.075015    111.140814                            57.140091
# 72              0.072940    122.210639                            57.140091
# 38              0.074128    125.103689                            57.140091
# 21              0.074391    129.568938                            57.140091
# 55              0.073801    101.138952                            57.140091
# 89              0.070265    146.604579                            57.140091
#
#     publicvoiceandgovaccountabilityindex
# 4                              -1.889918
# 72                             -1.979124
# 38                             -1.904177
# 21                             -1.889918
# 55                             -1.918437
# 89                             -2.039811

# %%
#drop the rows from 1995 to 2000 with null values
#these rows will be replaced with the imputed values for Myanmar
copy = df_agri.copy()

copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 1995)].index)
copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 1996)].index)
copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 1997)].index)
copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 1998)].index)
copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 1999)].index)
copy = copy.drop(copy[(copy['Country'] == 'Myanmar') & (copy['Year'] == 2000)].index)

# %%
#concatenate dataframes of Myanmar with imputed values and main df
frames = [df_myanmar, copy]
df_agri_myanmar = pd.concat(frames)

# %%
#last missing values are for Canada and USA
isna = df_agri_myanmar[df_agri_myanmar.isna().any(axis=1)]
isna
# Out:
#            Country  Year  overallreadiness  socialreadiness  \
# 10          Canada  1995          0.143769         0.459899
# 16   United States  1995          0.150419         0.559863
# 27          Canada  1996          0.142878         0.465221
# 33   United States  1996          0.146189         0.565382
# 418         Canada  2019          0.073622         0.558728
#
#      economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 10            0.485895             0.827835                0.400140  0.433494
# 16            0.522559             0.786576                0.428386  0.481034
# 27            0.485895             0.827835                0.402541  0.433494
# 33            0.522559             0.786576                0.429227  0.481034
# 418           0.587067             0.820527                0.390243  0.433494
#
#      foodvulnerability  habitatvulnerability  healthvulnerability  \
# 10            0.243380              0.504988             0.291677
# 16            0.357600              0.449454             0.141045
# 27            0.242477              0.504633             0.291677
# 33            0.356993              0.450052             0.273476
# 418           0.237581              0.517514             0.171418
#
#      watervulnerability  overallvulnerability  GDPPerCapita  \
# 10             0.204685             -0.097689   20613.78788
# 16             0.276116             -0.072398   28690.87570
# 27             0.204685             -0.095765   21227.34753
# 33             0.276116             -0.046006   29967.71272
# 418            0.203242             -0.029933   46328.67184
#
#      PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 10                                   NaN                              1.566336
# 16                                   NaN                              1.348661
# 27                                   NaN                              1.566336
# 33                                   NaN                              1.348661
# 418                                  NaN                              1.431915

# %% [markdown]
# ## For United States
#    - The 1997 value of the variable for USA will be assigned to the missing values from 1995 to 1996.

# %%
col = [1995, 1996, 1997]
df_usa = df_agri[df_agri.Country == 'United States'][df_agri['Year'].isin(col)]
df_usa
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/2740485076.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_usa = df_agri[df_agri.Country == 'United States'][df_agri['Year'].isin(col)]
#           Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 16  United States  1995          0.150419         0.559863           0.522559
# 50  United States  1997          0.140116         0.564317           0.522559
# 33  United States  1996          0.146189         0.565382           0.522559
#
#     governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 16             0.786576                0.428386  0.481034           0.357600
# 50             0.790694                0.432029  0.481034           0.356300
# 33             0.786576                0.429227  0.481034           0.356993
#
#     habitatvulnerability  healthvulnerability  watervulnerability  \
# 16              0.449454             0.141045            0.276116
# 50              0.450275             0.272064            0.276116
# 33              0.450052             0.273476            0.276116
#
#     overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 16             -0.072398   28690.87570                                  NaN
# 50             -0.040973   31459.13898                             1.336912
# 33             -0.046006   29967.71272                                  NaN
#
#     publicvoiceandgovaccountabilityindex
# 16                              1.348661
# 50                              1.342769
# 33                              1.348661

# %%
df_usa['PercGDPContributionOfAgriForestFish'] = df_usa['PercGDPContributionOfAgriForestFish'].fillna(1.336912)
yrs = [1995, 1996]
df_usa = df_usa[df_usa['Year'].isin(yrs)]

# %%
copy = df_agri_myanmar.copy()

copy = copy.drop(copy[(copy['Country'] == 'United States') & (copy['Year'] == 1995)].index)
copy = copy.drop(copy[(copy['Country'] == 'United States') & (copy['Year'] == 1996)].index)

# %%
frames = [df_usa, copy]
df_agri_usa = pd.concat(frames)

# %%
#last missing values are for Canada only
isna = df_agri_usa[df_agri_usa.isna().any(axis=1)]
isna
# Out:
#     Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 10   Canada  1995          0.143769         0.459899           0.485895
# 27   Canada  1996          0.142878         0.465221           0.485895
# 418  Canada  2019          0.073622         0.558728           0.587067
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 10              0.827835                0.400140  0.433494           0.243380
# 27              0.827835                0.402541  0.433494           0.242477
# 418             0.820527                0.390243  0.433494           0.237581
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 10               0.504988             0.291677            0.204685
# 27               0.504633             0.291677            0.204685
# 418              0.517514             0.171418            0.203242
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 10              -0.097689   20613.78788                                  NaN
# 27              -0.095765   21227.34753                                  NaN
# 418             -0.029933   46328.67184                                  NaN
#
#      publicvoiceandgovaccountabilityindex
# 10                               1.566336
# 27                               1.566336
# 418                              1.431915

# %% [markdown]
# ## For Canada (1995, 1996 values)
# - The 1997 value of the variable for Canada will be assigned to the missing values from 1995 to 1996.

# %%
col = [1995, 1996, 1997]
df_canada = df_agri[df_agri.Country == 'Canada'][df_agri['Year'].isin(col)]
df_canada
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/1534172417.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df_agri[df_agri.Country == 'Canada'][df_agri['Year'].isin(col)]
#    Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 10  Canada  1995          0.143769         0.459899           0.485895
# 44  Canada  1997          0.140332         0.473758           0.485895
# 27  Canada  1996          0.142878         0.465221           0.485895
#
#     governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 10             0.827835                0.400140  0.433494           0.243380
# 44             0.828824                0.402758  0.433494           0.240194
# 27             0.827835                0.402541  0.433494           0.242477
#
#     habitatvulnerability  healthvulnerability  watervulnerability  \
# 10              0.504988             0.291677            0.204685
# 44              0.504097             0.291677            0.204685
# 27              0.504633             0.291677            0.204685
#
#     overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 10             -0.097689   20613.78788                                  NaN
# 44             -0.092429   21901.56285                             2.139498
# 27             -0.095765   21227.34753                                  NaN
#
#     publicvoiceandgovaccountabilityindex
# 10                              1.566336
# 44                              1.558874
# 27                              1.566336

# %%
df_canada['PercGDPContributionOfAgriForestFish'] = df_canada['PercGDPContributionOfAgriForestFish'].fillna(2.139498)
yrs = [1995, 1996]
df_canada = df_canada[df_canada['Year'].isin(yrs)]
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/139088838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_canada['PercGDPContributionOfAgriForestFish'] = df_canada['PercGDPContributionOfAgriForestFish'].fillna(2.139498)

# %%
copy = df_agri_usa.copy()

copy = copy.drop(copy[(copy['Country'] == 'Canada') & (copy['Year'] == 1995)].index)
copy = copy.drop(copy[(copy['Country'] == 'Canada') & (copy['Year'] == 1996)].index)

# %%
frames = [df_canada, copy]
df_agri_canada = pd.concat(frames)

# %%
#Last missing value for Canada in 2019
isna = df_agri_canada[df_agri_canada.isna().any(axis=1)]
isna
# Out:
#     Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 418  Canada  2019          0.073622         0.558728           0.587067
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 418             0.820527                0.390243  0.433494           0.237581
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 418              0.517514             0.171418            0.203242
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 418             -0.029933   46328.67184                                  NaN
#
#      publicvoiceandgovaccountabilityindex
# 418                              1.431915

# %% [markdown]
# ## For the 2019 Value of Canada
#    - There is also a missing value from 2019. The average of 2018 and 2020 values for the variable for Canada will be assigned to the missing value.

# %%
col = [2018, 2019, 2020]
df_canada = df_agri_canada[df_agri_canada.Country == 'Canada'][df_agri_canada['Year'].isin(col)]
df_canada
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/88087449.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_canada = df_agri_canada[df_agri_canada.Country == 'Canada'][df_agri_canada['Year'].isin(col)]
#     Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 435  Canada  2020          0.084630         0.558068           0.594394
# 401  Canada  2018          0.080420         0.562686           0.592158
# 418  Canada  2019          0.073622         0.558728           0.587067
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 435             0.828305                0.390243  0.433494           0.237562
# 401             0.821466                0.390243  0.433494           0.237179
# 418             0.820527                0.390243  0.433494           0.237581
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 435              0.512965             0.162663            0.203242
# 401              0.515746             0.171418            0.203242
# 418              0.517514             0.171418            0.203242
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 435             -0.036343   43258.26387                             1.794943
# 401             -0.032641   46548.63841                             1.699892
# 418             -0.029933   46328.67184                                  NaN
#
#      publicvoiceandgovaccountabilityindex
# 435                              1.476175
# 401                              1.490146
# 418                              1.431915

# %%
col = ['PercGDPContributionOfAgriForestFish']
df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
df_canada = df_canada[df_canada['Year'].isin([2019])]
#value imputed for 2019
df_canada
# Out:
# /var/folders/df/p9jdn9zx63q013z8kqw587m80000gn/T/ipykernel_1276/147297150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_canada[col] = df_canada[col].fillna(df_canada[col].mean())
#     Country  Year  overallreadiness  socialreadiness  economicreadiness  \
# 418  Canada  2019          0.073622         0.558728           0.587067
#
#      governmentreadiness  ecosystemvulnerability  exposure  foodvulnerability  \
# 418             0.820527                0.390243  0.433494           0.237581
#
#      habitatvulnerability  healthvulnerability  watervulnerability  \
# 418              0.517514             0.171418            0.203242
#
#      overallvulnerability  GDPPerCapita  PercGDPContributionOfAgriForestFish  \
# 418             -0.029933   46328.67184                             1.747417
#
#      publicvoiceandgovaccountabilityindex
# 418                              1.431915

# %%
copy = df_agri_canada.copy()
#drop 2019 canada row with null value
copy = copy.drop(copy[(copy['Country'] == 'Canada') & (copy['Year'] == 2019)].index)

# %%
#concatenate imputed 2019 canada df and main df
frames = [df_canada, copy]
preprocessed_df = pd.concat(frames)

# %%
#correct number of entries from initial dataset, no more null values
preprocessed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 418 to 424
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               442 non-null    object
#  1   Year                                  442 non-null    int64
#  2   overallreadiness                      442 non-null    float64
#  3   socialreadiness                       442 non-null    float64
#  4   economicreadiness                     442 non-null    float64
#  5   governmentreadiness                   442 non-null    float64
#  6   ecosystemvulnerability                442 non-null    float64
#  7   exposure                              442 non-null    float64
#  8   foodvulnerability                     442 non-null    float64
#  9   habitatvulnerability                  442 non-null    float64
#  10  healthvulnerability                   442 non-null    float64
#  11  watervulnerability                    442 non-null    float64
#  12  overallvulnerability                  442 non-null    float64
#  13  GDPPerCapita                          442 non-null    float64
#  14  PercGDPContributionOfAgriForestFish   442 non-null    float64
#  15  publicvoiceandgovaccountabilityindex  442 non-null    float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 58.7+ KB

# %% [markdown]
# # Convert Final Preprocessed Dataset to CSV

# %%
preprocessed_df.head()
# Out:
#            Country  Year  overallreadiness  socialreadiness  \
# 418         Canada  2019          0.073622         0.558728
# 10          Canada  1995          0.143769         0.459899
# 27          Canada  1996          0.142878         0.465221
# 16   United States  1995          0.150419         0.559863
# 33   United States  1996          0.146189         0.565382
#
#      economicreadiness  governmentreadiness  ecosystemvulnerability  exposure  \
# 418           0.587067             0.820527                0.390243  0.433494
# 10            0.485895             0.827835                0.400140  0.433494
# 27            0.485895             0.827835                0.402541  0.433494
# 16            0.522559             0.786576                0.428386  0.481034
# 33            0.522559             0.786576                0.429227  0.481034
#
#      foodvulnerability  habitatvulnerability  healthvulnerability  \
# 418           0.237581              0.517514             0.171418
# 10            0.243380              0.504988             0.291677
# 27            0.242477              0.504633             0.291677
# 16            0.357600              0.449454             0.141045
# 33            0.356993              0.450052             0.273476
#
#      watervulnerability  overallvulnerability  GDPPerCapita  \
# 418            0.203242             -0.029933   46328.67184
# 10             0.204685             -0.097689   20613.78788
# 27             0.204685             -0.095765   21227.34753
# 16             0.276116             -0.072398   28690.87570
# 33             0.276116             -0.046006   29967.71272
#
#      PercGDPContributionOfAgriForestFish  publicvoiceandgovaccountabilityindex
# 418                             1.747417                              1.431915
# 10                              2.139498                              1.566336
# 27                              2.139498                              1.566336
# 16                              1.336912                              1.348661
# 33                              1.336912                              1.348661

# %%
preprocessed_df.isnull().sum()
# Out:
# Country                                 0
# Year                                    0
# overallreadiness                        0
# socialreadiness                         0
# economicreadiness                       0
# governmentreadiness                     0
# ecosystemvulnerability                  0
# exposure                                0
# foodvulnerability                       0
# habitatvulnerability                    0
# healthvulnerability                     0
# watervulnerability                      0
# overallvulnerability                    0
# GDPPerCapita                            0
# PercGDPContributionOfAgriForestFish     0
# publicvoiceandgovaccountabilityindex    0
# dtype: int64

# %%
preprocessed_df.to_csv('preprocessed_dataset.csv')
